# %% [markdown]
# visualizando datasets

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('datasets/WDIData.csv')

data.head(10)
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
# 5   Arab World          ARB
# 6   Arab World          ARB
# 7   Arab World          ARB
# 8   Arab World          ARB
# 9   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05   NaN
# 1  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05   NaN
# 2  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
# 5  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS   NaN
# 6                           Account (% age 15+) [ts]       WP_time_10.1   NaN
# ...

# %%
data[data['Indicator Name']=='Central government debt, total (% of GDP)']
# Out:
#                           Country Name Country Code  \
# 158                         Arab World          ARB
# 1677            Caribbean small states          CSS
# 3196    Central Europe and the Baltics          CEB
# 4715        Early-demographic dividend          EAR
# 6234               East Asia & Pacific          EAS
# ...                                ...          ...
# 393579           Virgin Islands (U.S.)          VIR
# 395098              West Bank and Gaza          PSE
# 396617                     Yemen, Rep.          YEM
# 398136                          Zambia          ZMB
# 399655                        Zimbabwe          ZWE
#
#                                    Indicator Name     Indicator Code  1960  \
# 158     Central government debt, total (% of GDP)  GC.DOD.TOTL.GD.ZS   NaN
# 1677    Central government debt, total (% of GDP)  GC.DOD.TOTL.GD.ZS   NaN
# 3196    Central government debt, total (% of GDP)  GC.DOD.TOTL.GD.ZS   NaN
# ...

# %%
central_govt_debt = data[data['Indicator Name']=='Central government debt, total (% of GDP)']
military_exp = data[data['Indicator Name']=='Military expenditure (% of GDP)']

# %%
central_govt_debt_2010 = debt_series = central_govt_debt[central_govt_debt['2010'].notna()][['', '2010']]
military_exp_2010 = military_exp['2010'].loc[~pd.isnull(military_exp['2010'])]

# %%
data_to_plot = pd.concat((central_govt_debt_2010, military_exp_2010), axis=1)
data_to_plot.columns = ['central_govt_debt', 'military_exp']

# %%
data_to_plot
# Out:
#         central_govt_debt  military_exp
# 835                   NaN      5.117807
# 3196            47.446156           NaN
# 3873                  NaN      1.482543
# 5392                  NaN      2.335511
# 6911                  NaN      1.563325
# ...                   ...           ...
# 391218                NaN      0.853924
# 392737                NaN      2.305049
# 397294                NaN      4.685557
# 398813                NaN      1.382593
# 400332                NaN      0.977841
#
# [286 rows x 2 columns]
